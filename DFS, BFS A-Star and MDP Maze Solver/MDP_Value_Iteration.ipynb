# %% [markdown]
# ### Import Libraries
# #### Please use pip install pyamaze before running this code if not already executed

# %%
from pyamaze import maze, agent, COLOR, textLabel
import tracemalloc as memory_trace
import time
from IPython.display import display
import pandas as pd
import copy

# %% [markdown]
# ### Impelement MDP Value Iteration Algortihm Functionality

# %%
class MDP_Value_Iteration_Search : 
    
    def __init__(self, maze_size) : 
        self.maze_size = maze_size
    
    def load_maze(self) : 
        m = maze()
        maze_name = 'Maze_' + str(self.maze_size) + 'X' + str(self.maze_size)
        m.CreateMaze(loadMaze = maze_name + '.csv')
        return m
    
    def start_memory_tracing(self) :
        memory_trace.stop()
        memory_trace.start()
        
    def stop_memory_tracing(self) : 
        memory_size, memory_peak = memory_trace.get_traced_memory()
        return memory_size, memory_peak
    
    def initialize_maze(self) : 
        self.maze = self.load_maze()
        self.goal_node = self.maze._goal
        self.start_node = (self.maze_size, self.maze_size)
    
    def initialise_cost(self) : 
        self.transition_value = {node: 10 if node == self.maze._goal else 0 for node in self.maze.grid}
        self.transition_reward = {node: 100 if node == self.maze._goal else 0 for node in self.maze.grid}
        
        self.transition_dictionary = copy.deepcopy(self.maze.maze_map)
        for key in self.transition_dictionary : 
            for subkey in self.transition_dictionary[key] : 
                self.transition_dictionary[key][subkey] = 0
        
        self.initial_transition_value = {}
        self.initial_transition_value['N'] = 1
        self.initial_transition_value['S'] = 1
        self.initial_transition_value['E'] = 1
        self.initial_transition_value['W'] = 1
        
        self.gamma = 0.9
        self.threshold = 0.000001
    
    def execute_mdp_value_iteration_search(self):

        self.initialize_maze()
        self.initialise_cost()

        start_time = time.time() * 1000
        self.start_memory_tracing()
        has_value_converged = False
    
        while not has_value_converged : 
            has_value_converged = True
           
            for current_node in self.maze.grid : 
                
               
                temp_transition_value = []
                
                for __direction__ in ['N', 'S', 'E', 'W']:
                    
                    if self.maze.maze_map[current_node][__direction__] == 1 :
                        
                        try:
                            if __direction__ == 'N' : 
                                next_node = (current_node[0] - 1, current_node[1])

                            elif __direction__ == 'S' : 
                                next_node = (current_node[0] + 1, current_node[1])

                            elif __direction__ == 'E' : 
                                next_node = (current_node[0], current_node[1] + 1)

                            elif __direction__ == 'W' : 
                                next_node = (current_node[0], current_node[1] - 1)
                        except:
                            next_node = None

                        if next_node is not None:
                            next_transtion_value = self.initial_transition_value[__direction__] * (self.transition_reward[current_node] + self.transition_value[next_node] * self.gamma)
                            temp_transition_value.append(next_transtion_value)
                            self.transition_dictionary[current_node][__direction__] = next_transtion_value
                
                best_transtion_value = (max(temp_transition_value))
                
                if abs(best_transtion_value - self.transition_value[current_node]) > self.threshold : 
                    has_value_converged = False
                    self.transition_value[current_node] = best_transtion_value
        
        end_time = time.time() * 1000
        time_taken = (end_time - start_time)
        
        memory_size, memory_peak = self.stop_memory_tracing()
        memory_consumed = round((memory_peak/(1024*1024)), 3)
        goal_nodes = self.find_goal_nodes(self.transition_dictionary, self.start_node, self.goal_node)
        
        statistics_df = pd.DataFrame(columns=['Maze Size', 'Time Taken (in ms)', 'Memory Consumed (in MB)', 'Number of Cell in Shortest Path to Goal'])
        statistics_dict = {}
        statistics_dict['Maze Size'] = str(self.maze_size) + 'X' + str(self.maze_size)
        statistics_dict['Time Taken (in ms)'] = time_taken
        statistics_dict['Memory Consumed (in MB)'] = memory_consumed
        statistics_dict['Number of Cell in Shortest Path to Goal'] = len(goal_nodes) + 1
        
        self.display_mdp_value_iteration_path(goal_nodes, time_taken, memory_consumed, len(goal_nodes) + 1)
        
        statistics_df = statistics_df.append(statistics_dict, ignore_index = True)
        
        return statistics_df

    
    def find_goal_nodes(self, transition_dictionary, start_node, goal_node) : 
        goal_nodes = {}
        next_node_to_goal = [start_node]
        
        while len(next_node_to_goal) > 0 : 
            current_node = next_node_to_goal.pop()
            
            if current_node == goal_node : 
                break
            
            best_transition_policy = self.find_best_transition_direction(self.transition_dictionary[current_node])
            print(f'\nCurrent Cell: {current_node}, Best Transition State for this cell: {transition_dictionary[current_node]}, Best Transition Direction: {best_transition_policy}')
            if best_transition_policy == 'N' : 
                next_node = (current_node[0] - 1, current_node[1])

            elif best_transition_policy == 'S' : 
                next_node = (current_node[0] + 1, current_node[1])

            elif best_transition_policy == 'E' : 
                next_node = (current_node[0], current_node[1] + 1)

            elif best_transition_policy == 'W' : 
                next_node = (current_node[0], current_node[1] - 1)
            
            goal_nodes[current_node] = next_node
            next_node_to_goal.append(next_node)
        
        return goal_nodes

    
    def find_best_transition_direction(self, current_node) : 
        transition_values = list(current_node.values())
        directions = list(current_node.keys())
        return directions[transition_values.index(max(transition_values))]
    
    def display_mdp_value_iteration_path(self, goal_nodes, time_taken, memory_consumed, len_goal_nodes) : 
        
        goal_path = agent(self.maze, x = self.maze_size, y = self.maze_size, footprints = True, color=COLOR.cyan) 
        self.maze.tracePath({goal_path : goal_nodes}, delay = 100)
        
        textLabel(self.maze, 'Maze Size ', str(self.maze_size) + 'X' + str(self.maze_size))
        textLabel(self.maze, 'Time Taken (in ms) ', time_taken)
        textLabel(self.maze, 'Memory Consumed (in MB) ', memory_consumed)
        textLabel(self.maze, 'Number of Cell in Shortest Path to Goal ', len_goal_nodes)
        
        self.maze.run()

# %% [markdown]
# ### Executing MDP Value Iteration for Maze Size 20 X 20

# %%
mdp_value_iteration_20 = MDP_Value_Iteration_Search(20)

statistics = mdp_value_iteration_20.execute_mdp_value_iteration_search()

statistics = statistics.style.applymap(lambda x:'white-space:nowrap')
display(statistics)
# Out:
# Current Cell: (20, 20), Best Transition State for this cell: {'E': 0, 'W': 0.50262952954014, 'N': 0.6205313753175258, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (19, 20), Best Transition State for this cell: {'E': 0, 'W': 0.6894802886495355, 'N': 0.5584782377857732, 'S': 0.5584782377857732}, Best Transition Direction: W
#
# Current Cell: (19, 19), Best Transition State for this cell: {'E': 0.6205313753175258, 'W': 0.766089209610595, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (19, 18), Best Transition State for this cell: {'E': 0.6894802886495355, 'W': 0, 'N': 0.8512112156418341, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (18, 18), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0
 'S': 0}, Best Transition Direction: N
#
# Current Cell: (5, 2), Best Transition State for this cell: {'E': 0, 'W': 133.78240782773508, 'N': 0, 'S': 108.36374954444507}, Best Transition Direction: W
#
# Current Cell: (5, 1), Best Transition State for this cell: {'E': 120.40416616049453, 'W': 0, 'N': 148.64711980859454, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (4, 1), Best Transition State for this cell: {'E': 165.1634674367351, 'W': 0, 'N': 0, 'S': 133.78240782773508}, Best Transition Direction: E
#
# Current Cell: (4, 2), Best Transition State for this cell: {'E': 0, 'W': 148.64711980859454, 'N': 183.51496381859454, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (3, 2), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 203.90551633673508, 'S': 165.1634674367351}, Best Transition Direction: N
#
# Current Cell: (2, 2), Best Transition State for this cell: {'E': 226.56168481859453, 'W': 0, 'N': 0, 'S': 183.51496381859454}, Best Transition Direction: E
#
# Current Cell: (2, 3), Best Transition State for this cell: {'E': 0, 'W': 203.90551633673508, 'N': 0, 'S': 251.73520633673508}, Best Transition Direction: S
#
# Current Cell: (3, 3), Best Transition State for this cell: {'E': 279.7057848185945, 'W': 0, 'N': 226.56168481859453, 'S': 0}, Best Transition Direction: E
#
# Current Cell: (3, 4), Best Transition State for this cell: {'E': 0, 'W': 251.73520633673508, 'N': 310.7842063367351, 'S': 251.73520633673508}, Best Transition Direction: N
#
# Current Cell: (2, 4), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 345.3157848185946, 'S': 279.7057848185945}, Best Transition Direction: N
#
# Current Cell: (1, 4), Best Transition State for this cell: {'E': 0, 'W': 383.68420633673514, 'N': 0, 'S': 310.7842063367351}, Best Transition Direction: W
#
# Current Cell: (1, 3), Best Transition State for this cell: {'E': 345.3157848185946, 'W': 426.3157848185946, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (1, 2), Best Transition State for this cell: {'E': 383.68420633673514, 'W': 473.68420633673514, 'N': 0, 'S': 0}, Best Transition Direction: W
# <style  type="text/css" >
# #T_8c771_row0_col0,#T_8c771_row0_col1,#T_8c771_row0_col2,#T_8c771_row0_col3{
#             white-space: nowrap;
#         }</style><table id="T_8c771_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maze Size</th>        <th class="col_heading level0 col1" >Time Taken (in ms)</th>        <th class="col_heading level0 col2" >Memory Consumed (in MB)</th>        <th class="col_heading level0 col3" >Number of Cell in Shortest Path to Goal</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c771_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8c771_row0_col0" class="data row0 col0" >20X20</td>
#                         <td id="T_8c771_row0_col1" class="data row0 col1" >136.666992</td>
#                         <td id="T_8c771_row0_col2" class="data row0 col2" >0.029000</td>
#                         <td id="T_8c771_row0_col3" class="data row0 col3" >65</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Executing MDP Value Iteration for Maze Size 30 X 30

# %%
mdp_value_iteration_30 = MDP_Value_Iteration_Search(30)

statistics = mdp_value_iteration_30.execute_mdp_value_iteration_search()

statistics = statistics.style.applymap(lambda x:'white-space:nowrap')
display(statistics)
# Out:
# Current Cell: (30, 30), Best Transition State for this cell: {'E': 0, 'W': 0.013975028535276934, 'N': 0.01725421358312726, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (29, 30), Best Transition State for this cell: {'E': 0, 'W': 0.019172331166870445, 'N': 0, 'S': 0.015528792224814533}, Best Transition Direction: W
#
# Current Cell: (29, 29), Best Transition State for this cell: {'E': 0.01725421358312726, 'W': 0.021302590185411606, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (29, 28), Best Transition State for this cell: {'E': 0.019172331166870445, 'W': 0, 'N': 0.023670527391630815, 'S': 0}, Best Transition Direction: N
#
# Current Cell:
_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maze Size</th>        <th class="col_heading level0 col1" >Time Taken (in ms)</th>        <th class="col_heading level0 col2" >Memory Consumed (in MB)</th>        <th class="col_heading level0 col3" >Number of Cell in Shortest Path to Goal</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89adc_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_89adc_row0_col0" class="data row0 col0" >30X30</td>
#                         <td id="T_89adc_row0_col1" class="data row0 col1" >331.145264</td>
#                         <td id="T_89adc_row0_col2" class="data row0 col2" >0.064000</td>
#                         <td id="T_89adc_row0_col3" class="data row0 col3" >99</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Executing MDP Value Iteration for Maze Size 40 X 40

# %%
mdp_value_iteration_40 = MDP_Value_Iteration_Search(40)

statistics = mdp_value_iteration_40.execute_mdp_value_iteration_search()

statistics = statistics.style.applymap(lambda x:'white-space:nowrap')
display(statistics)
# Out:
# Current Cell: (40, 40), Best Transition State for this cell: {'E': 0, 'W': 0.0008985837170999086, 'N': 0.0007269683437947913, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 39), Best Transition State for this cell: {'E': 0.0008087253453899178, 'W': 0.0008087253453899178, 'N': 0.000999409093506714, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (39, 39), Best Transition State for this cell: {'E': 0, 'W': 0.0011104545483407932, 'N': 0, 'S': 0.0008985837170999086}, Best Transition Direction: W
#
# Current Cell: (39, 38), Best Transition State for this cell: {'E': 0.000999409093506714, 'W': 0.0012348211282188109, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (39, 37), Best Transition State for this cell: {'E': 0.0011104545483407932, 'W': 0.0011104545483407932, 'N': 0.0011104545483407932, 'S': 0.0013720234757986787}, Best Transition Direction: S
#
# Current Cell: (40, 37), Best Transition State for this cell: {'E': 0, 'W': 0.0015254532698386802, 'N': 0.0012348211282188109, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 36), Best Transition State for this cell: {'E': 0.0013720234757986787, 'W': 0.0016949480775985334, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 35), Best Transition State for this cell: {'E': 0.0015254532698386802, 'W': 0.0018842583829496323, 'N': 0.0015254532698386802, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 34), Best Transition State for this cell: {'E': 0.0016949480775985334, 'W': 0.0020936204254995913, 'N': 0.0020936204254995913, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 33), Best Transition State for this cell: {'E': 0.0018842583829496323, 'W': 0.0023272276583952522, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 32), Best Transition State for this cell: {'E': 0.0020936204254995913, 'W': 0.002585808509328058, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (40, 31), Best Transition State for this cell: {'E': 0.0023272276583952522, 'W': 0, 'N': 0.002874103307093547, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (39, 31), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.00319344811899283, 'S': 0.002585808509328058}, Best Transition Direction: N
#
# Current Cell: (38, 31), Best Transition State for this cell: {'E': 0, 'W': 0.003549258428943295, 'N': 0, 'S': 0.002874103307093547}, Best Transition Direction: W
#
# Current Cell: (38, 30), Best Transition State for this cell: {'E': 0.00319344811899283, 'W': 0.003943620476603661, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (38, 29), Best Transition State for this cell: {'E': 0.003549258428943295, 'W': 0.003549258428943295, 'N': 0.004382783270733105, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (37, 29), Best Transition State for this cell: {'E': 0.003943620476603661, 'W': 0, 'N': 0.0048697591897034495, 'S': 0.003943620476603661}, Best Transition Direction: N
#
# Current Cell: (36, 29), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.00541182628528843, 'S': 0.004382783270733105}, Best Transition Direction: N
#
# Current Cell: (35, 29), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0
 'S': 0}, Best Transition Direction: N
#
# Current Cell: (27, 23), Best Transition State for this cell: {'E': 0.06110392756039373, 'W': 0, 'N': 0.07543803954006156, 'S': 0.06110392756039373}, Best Transition Direction: N
#
# Current Cell: (26, 23), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.08382102667457528, 'S': 0.06789423558605541}, Best Transition Direction: N
#
# Current Cell: (25, 23), Best Transition State for this cell: {'E': 0, 'W': 0.09313447408286142, 'N': 0, 'S': 0.07543803954006156}, Best Transition Direction: W
#
# Current Cell: (25, 22), Best Transition State for this cell: {'E': 0.08382102667457528, 'W': 0.10348373172213061, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (25, 21), Best Transition State for this cell: {'E': 0.09313447408286142, 'W': 0, 'N': 0.11498192413570069, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (24, 21), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.12775867622528525, 'S': 0.10348373172213061}, Best Transition Direction: N
#
# Current Cell: (23, 21), Best Transition State for this cell: {'E': 0, 'W': 0.1419540846947614, 'N': 0, 'S': 0.11498192413570069}, Best Transition Direction: W
#
# Current Cell: (23, 20), Best Transition State for this cell: {'E': 0.12775867622528525, 'W': 0, 'N': 0, 'S': 0.15772774351313068}, Best Transition Direction: S
#
# Current Cell: (24, 20), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.1419540846947614, 'S': 0.17525304834792296}, Best Transition Direction: S
#
# Current Cell: (25, 20), Best Transition State for this cell: {'E': 0, 'W': 0.1947265920166435, 'N': 0.15772774351313068, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (25, 19), Best Transition State for this cell: {'E': 0.17525304834792296, 'W': 0, 'N': 0.21636288001849277, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (24, 19), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.24040418276172096, 'S': 0.1947265920166435}, Best Transition Direction: N
#
# Current Cell: (23, 19), Best Transition State for this cell: {'E': 0, 'W': 0.2671157586241344, 'N': 0, 'S': 0.21636288001849277}, Best Transition Direction: W
#
# Current Cell: (23, 18), Best Transition State for this cell: {'E': 0.24040418276172096, 'W': 0, 'N': 0.24040418276172096, 'S': 0.2967962701013228}, Best Transition Direction: S
#
# Current Cell: (24, 18), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 0.2671157586241344, 'S': 0.3297736334459142}, Best Transition Direction: S
#
# Current Cell: (25, 18), Best Transition State for this cell: {'E': 0, 'W': 0.36641613101441123, 'N': 0.2967962701013228, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (25, 17), Best Transition State for this cell: {'E': 0.3297736334459142, 'W': 0, 'N': 0.4071290344604569, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (24, 17), Best Transition State for this cell: {'E': 0, 'W': 0.36641613101441123, 'N': 0.45236657658612595, 'S': 0.36641613101441123}, Best Transition Direction: N
#
# Current Cell: (23, 17), Best Transition State for this cell: {'E': 0, 'W': 0.50262952954014, 'N': 0.4071290344604569, 'S': 0.4071290344604569}, Best Transition Direction: W
#
# Current Cell: (23, 16), Best Transition State for this cell: {'E': 0.45236657658612595, 'W': 0.5584782377857732, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (23, 15), Best Transition State for this cell: {'E': 0.50262952954014, 'W': 0.50262952954014, 'N': 0.6205313753175258, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (22, 15), Best Transition State for this cell: {'E': 0, 'W': 0.6894802886495355, 'N': 0, 'S': 0.5584782377857732}, Best Transition Direction: W
#
# Current Cell: (22, 14), Best Transition State for this cell: {'E': 0.6205313753175258, 'W': 0.766089209610595, 'N': 0.6205313753175258, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (22, 13), Best Transition State for this cell: {'E': 0.6894802886495355, 'W': 0, 'N': 0.8512112156418341, 'S': 0.6894802886495355}, Best Transition Direction: N
#
# Current Cell: (21, 13), Best Transition State for this cell: {'E': 0, 'W': 0.9457902396020379, 'N': 0.766089209610595, 'S': 0.766089209610595}, Best Transition Direction: W
#
# Current Cell: (21, 12), Best Transition State for this cell: {'E': 0.8512112156418341, 'W': 0, 'N': 1.0508790267434387, 'S': 0.8512112156418341}, Best Transition Direction: N
#
# Current Cell: (20, 12), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 1.1676433630482652, 'S': 0.9457902396020379}, Best Transition Direction: N
#
# Current Cell: (19, 12), Best Transition State for this cell: {'E': 1.297382497239245, 'W': 0, 'N': 0, 'S': 1.0508790267434387}, Best Transition Direction: E
#
# Current Cell: (19, 13), Best Transition State for this cell: {'E': 0, 'W': 1.1676433630482652, 'N': 1.4415361080436055, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (18, 13), Best Transition State for this cell: {'E': 0, 'W': 1.6017077694562907, 'N': 0, 'S': 1.297382497239245}, Best Transition Direction: W
#
# Current Cell: (18, 12), Best Transition State for this cell: {'E': 1.4415361080436055, 'W': 0, 'N': 1.7796752993958784, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (17, 12), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 1.9774179820699287, 'S': 1.6017077694562907}, Best Transition Direction: N
#
# Current Cell: (16, 12), Best Transition State for this cell: {'E': 1.7796752993958784, 'W': 0, 'N': 2.1971310911888096, 'S': 1.7796752993958784}, Best Transition Direction: N
#
# Current Cell: (15, 12), Best Transition State for this cell: {'E': 0, 'W': 2.4412577507287376, 'N': 1.9774179820699287, 'S': 1.9774179820699287}, Best Transition Direction: W
#
# Current Cell: (15, 11), Best Transition State for this cell: {'E': 2.1971310911888096, 'W': 2.1971310911888096, 'N': 2.7125086119208195, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (14, 11), Best Transition State for this cell: {'E': 0, 'W': 3.0138994404309734, 'N': 0, 'S': 2.4412577507287376}, Best Transition Direction: W
#
# Current Cell: (14, 10), Best Transition State for this cell: {'E': 2.7125086119208195, 'W': 3.348777156034415, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (14, 9), Best Transition State for this cell: {'E': 3.0138994404309734, 'W': 3.7208644894460803, 'N': 0, 'S': 3.0138994404309734}, Best Transition Direction: W
#
# Current Cell: (14, 8), Best Transition State for this cell: {'E': 3.348777156034415, 'W': 4.134293877162311, 'N': 3.348777156034415, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (14, 7), Best Transition State for this cell: {'E': 3.7208644894460803, 'W': 4.593660846254853, 'N': 0, 'S': 3.7208644894460803}, Best Transition Direction: W
#
# Current Cell: (14, 6), Best Transition State for this cell: {'E': 4.134293877162311, 'W': 0, 'N': 5.104067606949836, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (13, 6), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 5.671187212685433, 'S': 4.593660846254853}, Best Transition Direction: N
#
# Current Cell: (12, 6), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 6.301319125206036, 'S': 5.104067606949836}, Best Transition Direction: N
#
# Current Cell: (11, 6), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 7.001466677414547, 'S': 5.671187212685433}, Best Transition Direction: N
#
# Current Cell: (10, 6), Best Transition State for this cell: {'E': 6.301319125206036, 'W': 0, 'N': 7.779407419349497, 'S': 6.301319125206036}, Best Transition Direction: N
#
# Current Cell: (9, 6), Best Transition State for this cell: {'E': 8.643787004240615, 'W': 0, 'N': 7.001466677414547, 'S': 7.001466677414547}, Best Transition Direction: E
#
# Current Cell: (9, 7), Best Transition State for this cell: {'E': 9.604207782489572, 'W': 7.779407419349497, 'N': 7.779407419349497, 'S': 0}, Best Transition Direction: E
#
# Current Cell: (9, 8), Best Transition State for this cell: {'E': 0, 'W': 8.643787004240615, 'N': 10.671342963285147, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (8, 8), Best Transition State for this cell: {'E': 11.857047736983496, 'W': 0, 'N': 0, 'S': 9.604207782489572}, Best Transition Direction: E
#
# Current Cell: (8, 9), Best Transition State for this cell: {'E': 0, 'W': 10.671342963285147, 'N': 0, 'S': 13.174498468278387}, Best Transition Direction: S
#
# Current Cell: (9, 9), Best Transition State for this cell: {'E': 14.63833163142043, 'W': 0, 'N': 11.857047736983496, 'S': 0}, Best Transition Direction: E
#
# Current Cell: (9, 10), Best Transition State for this cell: {'E': 0, 'W': 13.174498468278387, 'N': 0, 'S': 16.264813906541654}, Best Transition Direction: S
#
# Current Cell: (10, 10), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 14.63833163142043, 'S': 18.07201545171295}, Best Transition Direction: S
#
# Current Cell: (11, 10), Best Transition State for this cell: {'E': 20.080018151311105, 'W': 0, 'N': 16.264813906541654, 'S': 16.264813906541654}, Best Transition Direction: E
#
# Current Cell: (11, 11), Best Transition State for this cell: {'E': 0, 'W': 18.07201545171295, 'N': 22.311131279234562, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (10, 11), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 24.790146848557356, 'S': 20.080018151311105}, Best Transition Direction: N
#
# Current Cell: (9, 11), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 27.544607609508173, 'S': 22.311131279234562}, Best Transition Direction: N
#
# Current Cell: (8, 11), Best Transition State for this cell: {'E': 0, 'W': 0, 'N': 30.60512054886137, 'S': 24.790146848557356}, Best Transition Direction: N
#
# Current Cell: (7, 11), Best Transition State for this cell: {'E': 34.00568949873485, 'W': 0, 'N': 27.544607609508173, 'S': 27.544607609508173}, Best Transition Direction: E
#
# Current Cell: (7, 12), Best Transition State for this cell: {'E': 37.78410042577991, 'W': 30.60512054886137, 'N': 0, 'S': 0}, Best Transition Direction: E
#
# Current Cell: (7, 13), Best Transition State for this cell: {'E': 0, 'W': 34.00568949873485, 'N': 41.98233380642212, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (6, 13), Best Transition State for this cell: {'E': 37.78410042577991, 'W': 0, 'N': 46.647038545432416, 'S': 37.78410042577991}, Best Transition Direction: N
#
# Current Cell: (5, 13), Best Transition State for this cell: {'E': 51.830042828258236, 'W': 0, 'N': 0, 'S': 41.98233380642212}, Best Transition Direction: E
#
# Current Cell: (5, 14), Best Transition State for this cell: {'E': 0, 'W': 46.647038545432416, 'N': 57.58893745858363, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (4, 14), Best Transition State for this cell: {'E': 0, 'W': 51.830042828258236, 'N': 63.987708287315144, 'S': 51.830042828258236}, Best Transition Direction: N
#
# Current Cell: (3, 14), Best Transition State for this cell: {'E': 57.58893745858363, 'W': 0, 'N': 71.09745463531357, 'S': 57.58893745858363}, Best Transition Direction: N
#
# Current Cell: (2, 14), Best Transition State for this cell: {'E': 0, 'W': 78.99717181701507, 'N': 0, 'S': 63.987708287315144}, Best Transition Direction: W
#
# Current Cell: (2, 13), Best Transition State for this cell: {'E': 71.09745463531357, 'W': 87.77463633498014, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (2, 12), Best Transition State for this cell: {'E': 78.99717181701507, 'W': 97.52737370553349, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (2, 11), Best Transition State for this cell: {'E': 87.77463633498014, 'W': 0, 'N': 108.36374954444507, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (1, 11), Best Transition State for this cell: {'E': 0, 'W': 120.40416616049453, 'N': 0, 'S': 97.52737370553349}, Best Transition Direction: W
#
# Current Cell: (1, 10), Best Transition State for this cell: {'E': 108.36374954444507, 'W': 133.78240782773508, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (1, 9), Best Transition State for this cell: {'E': 120.40416616049453, 'W': 148.64711980859454, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (1, 8), Best Transition State for this cell: {'E': 133.78240782773508, 'W': 165.1634674367351, 'N': 0, 'S': 133.78240782773508}, Best Transition Direction: W
#
# Current Cell: (1, 7), Best Transition State for this cell: {'E': 148.64711980859454, 'W': 0, 'N': 0, 'S': 183.51496381859454}, Best Transition Direction: S
#
# Current Cell: (2, 7), Best Transition State for this cell: {'E': 0, 'W': 203.90551633673508, 'N': 165.1634674367351, 'S': 165.1634674367351}, Best Transition Direction: W
#
# Current Cell: (2, 6), Best Transition State for this cell: {'E': 183.51496381859454, 'W': 0, 'N': 226.56168481859453, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (1, 6), Best Transition State for this cell: {'E': 0, 'W': 251.73520633673508, 'N': 0, 'S': 203.90551633673508}, Best Transition Direction: W
#
# Current Cell: (1, 5), Best Transition State for this cell: {'E': 226.56168481859453, 'W': 279.7057848185945, 'N': 0, 'S': 0}, Best Transition Direction: W
#
# Current Cell: (1, 4), Best Transition State for this cell: {'E': 251.73520633673508, 'W': 310.7842063367351, 'N': 0, 'S': 251.73520633673508}, Best Transition Direction: W
#
# Current Cell: (1, 3), Best Transition State for this cell: {'E': 279.7057848185945, 'W': 0, 'N': 0, 'S': 345.3157848185946}, Best Transition Direction: S
#
# Current Cell: (2, 3), Best Transition State for this cell: {'E': 0, 'W': 383.68420633673514, 'N': 310.7842063367351, 'S': 310.7842063367351}, Best Transition Direction: W
#
# Current Cell: (2, 2), Best Transition State for this cell: {'E': 345.3157848185946, 'W': 0, 'N': 426.3157848185946, 'S': 0}, Best Transition Direction: N
#
# Current Cell: (1, 2), Best Transition State for this cell: {'E': 0, 'W': 473.68420633673514, 'N': 0, 'S': 383.68420633673514}, Best Transition Direction: W
# <style  type="text/css" >
# #T_f0ced_row0_col0,#T_f0ced_row0_col1,#T_f0ced_row0_col2,#T_f0ced_row0_col3{
#             white-space: nowrap;
#         }</style><table id="T_f0ced_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Maze Size</th>        <th class="col_heading level0 col1" >Time Taken (in ms)</th>        <th class="col_heading level0 col2" >Memory Consumed (in MB)</th>        <th class="col_heading level0 col3" >Number of Cell in Shortest Path to Goal</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f0ced_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f0ced_row0_col0" class="data row0 col0" >40X40</td>
#                         <td id="T_f0ced_row0_col1" class="data row0 col1" >606.377197</td>
#                         <td id="T_f0ced_row0_col2" class="data row0 col2" >0.112000</td>
#                         <td id="T_f0ced_row0_col3" class="data row0 col3" >127</td>
#             </tr>
#     </tbody></table>
